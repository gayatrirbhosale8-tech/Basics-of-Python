# %% [markdown]
# #Experiment No.6
# ##Study of condition statement in python
# ###Name: Gayatri Bhosale
# ###PRN: 25070123033

# %%
#1a. Check wheather a number is positive, negative
number = int(input("Enter a number"))
if(number > 0):
   print("The nuuber is POSITIVE")
elif(number < 0):
  print("The nuber is NEGATIVE")
else:
  print(ZERO)
# Out:
# Enter a number4
# The nuuber is POSITIVE

# %%
#2.Check wheather a number  is odd or even
number = int(input("Enter a number"))
if number % 2 == 0:
   print("The number is EVEN")
else:
  print("The number is ODD")
# Out:
# Enter a number88
# The number is EVEN

# %%
#3. Find the largest of two numbers
d = int(input("Enter first number: "))
e = int(input("Enter second number: "))
if d>e:
  print("Largest:" , d)
elif b>=a and b>=c:
  print("Largest:", e)
# Out:
# Enter first number: 6
# Enter second number: 3
# Largest: 6

# %%
#4. Find the largest of the three numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a>=b and a>=c:
  print("Largest:" , a)
elif b>=a and b>=c:
  print("Largest:", b)
else:
  print("Largest:", c)
# Out:
# Enter first number: 7
# Enter second number: 9
# Enter third number: 8
# Largest: 9

# %%
#5. Get input from the user for 5 subjects and find average
#calculate grade using if-elif-else.

AMT = int(input("Enter AMT Marks: "))
IKS = int(input("Enter IKS Marks: "))
PES = int(input("Enter PES Marks: "))
PC = int(input("Enter C++ Marks: "))
EDP = int(input("Enter EDP Marks: "))

avg= (AMT+IKS+PES+PC+EDP) / 5

if (avg>= 90):
  print("Grade is O")
elif(avg>=80):
  print("Grade is A+")
elif(avg>=70):
  print("Grade is A")
elif(avg>=60):
  print("Grade is B+")
elif(avg>=50):
  print("Grade is B")
else:
  print("STUDY HARDER")
# Out:
# Enter AMT Marks: 100
# Enter IKS Marks: 99
# Enter PES Marks: 88
# Enter C++ Marks: 95
# Enter EDP Marks: 98
# Grade is O

# %%
#6. Check whether a year is a leap year
year = int(input("Enter year:"))
if (year % 4==0 and year % 100!=0) or (year % 400 == 0):
  print ("Leap Year")
else:
  print("NOT A LEAP YEAR")
# Out:
# Enter year:2020
# Leap Year

# %%
# 7. Python Program to check if a date is valid and print the Incremented Date if it is valid
Date = input ("Enter the data in format {dd/mm/yyyy}")
dd,mm,yy=Date.split('/')
dd = int(dd)
mm = int(mm)
yy = int(yy)

if(m==1 or m==3 or m==5 or m==7 or m==8 or m == 10 or m== 12):
  max1=31
elif(m==4 or m==6 or m==9 or m==11):
  max1=30
elif(yy% 4 == 0 and y%100!=0 or yy% 400== 0):
  max1 = 29
else:
  max1=28
  if (m<1 or m>12):
    print("Date is invalid")
  elif(dd<1 or dd>max1):
    print("Date is invalid")
  elif(dd==max1 and mm!=12):
    dd=1
    mm=mm+1
    print("The incremented date is:" ,dd,mm,yy)
  elif(dd==31 and mm==12):
    dd=1
    mm=1
    yy=yy+1
    print("The incremented date is :",dd,mm,yy)
  else:
    dd=dd+1
    print("The Incremented date is: ",dd,mm,yy)
# Out:
# Enter the data in format {dd/mm/yyyy}26/01/2007
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4066228543.py in <cell line: 0>()
#       6 yy = int(yy)
#       7
# ----> 8 if(m==1 or m==3 or m==5 or m==7 or m==8 or m == 10 or m== 12):
#       9   max1=31
#      10 elif(m==4 or m==6 or m==9 or m==11):
#
# NameError: name 'm' is not defined

# %%
#9. Salary Calculations With Allowances
''' Problem Statement:
Write A Python Program To Calculate The Gross Salary Of An Employee Based On Basic Salary
If Basic <=10000: HRA =20%, DA = 80%
If Basic <=20000: HRA = 25% DA = 90%
Otherwise,HRA =30%,DA = 95%'''

BasicSalary=input("Enter The Current Salary")
hra = int(hra)
da = int(da)
GROSS = int(Gross_Salary)
if(BasicSalary<= 10000):
  GROSS=BasicSalary+BasicSalary*20/100+BasicSalary*80/100
  Print(" Your Gross Salary is:")
elif(BasicSalary<= 20000):
  GROSS=BasicSalary+BasicSalary*25/100+BasicSalary*90/100
  Print(" Your Gross Salary is:")
else:
    GROSS=BasicSalary+BasicSalary*30/100+BasicSalary*95/100
    Print(" Your Gross Salary is:")
# Out:
# Enter The Current Salary7000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3876861813.py in <cell line: 0>()
#       7
#       8 BasicSalary=input("Enter The Current Salary")
# ----> 9 hra = int(hra)
#      10 da = int(da)
#      11 GROSS = int(Gross_Salary)
#
# NameError: name 'hra' is not defined
