# %% [markdown]
# #Experiment No.5
# ##To Study Sets And Dictionaries In Python
# ###Name: Gayatri Bhosale
# ####PRN: 25070123033

# %%
# Creation of set
theset = {"dot","triangle","square","rectangle","hexagone"}
print(theset)
# Out:
# {'hexagone', 'triangle', 'rectangle', 'square', 'dot'}

# %%
# Duplicates not allowed
theset = {"dot","triangle","square","rectangle","hexagone","dot"}
print(theset)
# Out:
# {'hexagone', 'triangle', 'rectangle', 'square', 'dot'}

# %%
#The values True and 1 are considered the same value in sets, and are true
theset = {"dot","triangle","square","rectangle","hexagone",True,1,2}
print(theset)
# Out:
# {'triangle', True, 2, 'hexagone', 'rectangle', 'square', 'dot'}

# %%
#a set with strings,integers and boolean values:
thisset ={"fruit","34","true",7.7}
print(thisset)
# Out:
# {'fruit', '34', 'true', 7.7}

# %%
#TO CHECK THE MEMBERSHIP
theset = {"dot","triangle","square","rectangle","hexagone"}
print("triangle" in theset)
print("mall" in theset)
# Out:
# True
# False

# %%
#once a set is created, you cannot replace its iteams
#but you can add new items
theset = {"dot","triangle","square","rectangle","hexagone"}
theset.add("heptagoan")
print(theset)
# Out:
# {'hexagone', 'triangle', 'rectangle', 'heptagoan', 'square', 'dot'}

# %%
#remove an item
theset = {"dot","triangle","square","rectangle","hexagone"}
theset.remove("dot")
print(theset)
# Out:
# {'hexagone', 'triangle', 'rectangle', 'square'}

# %%
#set operations
A = {11,21,31,41}
B = {21,41,51,61}
print("uninon:",A|B)
print("intersection", A&B)
print("difference", A-B)
print("symmetric difference", A^B)
# Out:
# uninon: {41, 11, 51, 21, 61, 31}
# intersection {41, 21}
# difference {11, 31}
# symmetric difference {11, 51, 61, 31}

# %%
#PYTHON FROZENSET
x = frozenset({"dot","triangle","square"})
print(x)
print(type(x))
# Out:
# frozenset({'triangle', 'dot', 'square'})
# <class 'frozenset'>

# %%
#adding or removal of elements are not allowed in frozen
x = frozenset({"dot","triangle","square"})
x.remove("square")
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-191740761.py in <cell line: 0>()
#       1 #adding or removal of elements are not allowed in frozen
#       2 x = frozenset({"dot","triangle","square"})
# ----> 3 x.remove("square")
#       4 print(x)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
'''problem statement 1:unique event participants
acollege event has a list of students who registered multiple times by mistake
write a programe using set to store participats names and display only unique participants'''
students_names = ["gayatri","tannishtha","neha","bedang","arjit","dhvan","atharva","gayatri","neha","arjit"]
student_names1=set(students_names)
print("The names of college Students are",student_names1)
# Out:
# The names of college Students are {'neha', 'gayatri', 'arjit', 'atharva', 'dhvan', 'tannishtha', 'bedang'}

# %%
'''problem statement 2: three students choose elective subjects.
find the commmon subjectschoose by all the students using set operations.
conceptused:set interaction($)'''

GAYATRI = {"CHEMISTRY","PES","PYTHON"}
ARYA = {"IKS","MATHS","PES"}
MEHEK = {"ENGLISH","PYTHON","PES"}
SHREYA = {"FRENCH","CHEMISTRY","PES"}
SHRUTI = {"MARATHI","FRENCH","PES"}


print("COMMON SUBJECTS",GAYATRI&ARYA&MEHEK&SHREYA&SHRUTI)
# Out:
# COMMON SUBJECTS {'PES'}

# %%
'''PROBLEM STATEMENTS 3: ONE SET CONTAINS STUDENTS IN THE CRICKET CLUB ,ANOTHER IN THE FOOTBALL CLUB.
FIND STUDENTS WHO ARE:1 IN BOTH CLUBS . IN ONLY ONE CLUB
CNCEPT USED :iNTERSECTION,SYMMETRIC DIFFERENCE'''
CRICKET={"NEHA","GAYATRI","ARJIT","BEDANG","ATHARVA"}
FOOTBALL={"GAYATRI","ATHARVA","ARJIT","DHVAN","ANJI"}
print("students in BOTH clubs:",CRICKET&FOOTBALL)
print("students in ONE clubs:",CRICKET^FOOTBALL)
# Out:
# students in BOTH clubs: {'ARJIT', 'GAYATRI', 'ATHARVA'}
# students in ONE clubs: {'BEDANG', 'ANJI', 'NEHA', 'DHVAN'}

# %%
'''PROBLEM STATEMENTS 4: '''
PRESENTSTUDENTS={"NEHA","GAYATRI","ARJIT","BEDANG","ATHARVA"}
TOTALSTUDENTS={"ANSH","DHVAN","ANJI","TANMAY","DEV","NEHA","GAYATRI","ARJIT","BEDANG","ATHARVA"}
ABSENTSTUDENTS=TOTALSTUDENTS-PRESENTSTUDENTS
print("ABSENT STUDENTS:",ABSENTSTUDENTS)
# Out:
# ABSENT STUDENTS: {'DEV', 'TANMAY', 'DHVAN', 'ANSH', 'ANJI'}

# %%
'''PROBLEM STATEMENTS 5: '''
coursecode ={"ENTC701","ENTC703","ENTC705","ENTC707","ENTC709",}
coursecode.discard("ENTC701")
print("updated course:",coursecode)
# Out:
# updated course: {'ENTC705', 'ENTC709', 'ENTC703', 'ENTC707'}

# %%
#creation of dictinary
thedict = {"brand":"BMW",
"model": "X7",
"year": 2021
}
print(thedict["brand"])
# Out:
# BMW

# %%
thedict = {"brand":"BMW",
"model": "X7",
"year": 2021,
"year": 2023
}
print(thedict)
# Out:
# {'brand': 'BMW', 'model': 'X7', 'year': 2023}

# %%
#lenhgth of the key lue pairs
len(thedict)
# Out:
# 3

# %%
#changin/adding key value in dictionary
car = {"brand":"BMW",
"model": "X7",
"year": 2021
}
car["color"] = "black"
x = car.values()
print(x)
# Out:
# dict_values(['BMW', 'X7', 2021, 'black'])

# %%
# retrival of values
student = {
    "PRN": 101,
    "name":"Shruti",
    "branch": "ENTC"
}
print("Name:", student["name"])
# Out:
# Name: Shruti

# %%
#adding and updating eleents

student["year"] = "First"
student["name"] = "Shre"
print(student)
# Out:
# {'PRN': 101, 'name': 'Shre', 'branch': 'ENTC', 'year': 'First'}

# %%
#Removing Elements
student.pop("branch")
print("After removal:", student)
# Out:
# After removal: {'PRN': 101, 'name': 'Shre', 'year': 'First'}

# %%
'''1. a dictionary stores product names their prices.
write a python code to update the price of a given product.'''

thisdict_mall = {
    "Brand":"YSL",
    "Product Name": "Leather Jacket",
    "Price": 50000
}

print(thisdict_mall)

thisdict_mall["Price"] = 75000
print(thisdict_mall)
# Out:
# {'Brand': 'YSL', 'Product Name': 'Leather Jacket', 'Price': 50000}
# {'Brand': 'YSL', 'Product Name': 'Leather Jacket', 'Price': 75000}

# %%
'''2. a dictionary stores student names their marks.
write  a code to search far a student's marks using the name entry
if the sudent is not found , display a suitable message.'''
names_of_students = {
    "Gayatri": 100,
    "Rajvardhan": 90,
    "Shre":80,
    "Mahi":60,
    "Tanvi":70
}

name = input("Enter student name:")
print(names_of_students.get(name,"student not found"))
# Out:
# Enter student name:max
# student not found

# %%
'''3. a dictiobary stores username and passwords
write a python code to validate user login.'''

LoginID = {
    "username":"password",
    "doedoes" : 50505,
    "pumkin_munchkin": "heheheh",
    "sssuperstar":"bwahhhhh"
}

print(LoginID)

ID = input("Enter username:")
print(LoginID.get(ID,"username not validated"))
# Out:
# {'username': 'password', 'doedoes': 50505, 'pumkin_munchkin': 'heheheh', 'sssuperstar': 'bwahhhhh'}
# Enter username:doedoes
# 50505
# 50505

# %%
'''4. a dictionary stores student names and marks. Write a python program to find the student who scored the highest marks.'''
student_marks = {"pasta":85,"pizza":91,"panini":100}
Topper = max(student_marks, key=student_marks.get)
print("Topper:",Topper)
print("Marks:", student_marks[Topper])
# Out:
# Topper: panini
# Marks: 100
