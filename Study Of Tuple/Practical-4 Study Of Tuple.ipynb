# %% [markdown]
# #Expertiment NO.4
# Study Of Tuple

# %%
##pyhton tuples
#acessTuple items
thistuple = ("apple","banana","cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple","banana","cherry")
thistuple[1] = "blackcurrent"
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1411103077.py in <cell line: 0>()
#       1 thistuple = ("apple","banana","cherry")
# ----> 2 thistuple[1] = "blackcurrent"
#       3 print(thistuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (1,2,3)
t2 = (4,5)
t3 = t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
#Add Tuple to a tuple
thistuple = ("apple","banana", "cherry")

y = ("orange",)

# %%
#Add Tuple to a tuple
thistuple = ("apple","banana", "cherry")
print("Before:", id(thistuple))

y = ("orange",)
thistuple += y
print("After:", id(thistuple))
# Out:
# Before: 138048440555712
# After: 138047496027120

# %%
thistuple = ["apple","banana", "cherry"]
print("Before:", id(thistuple))

y = ["orange",]
thistuple += y
print("After:", id(thistuple))
# Out:
# Before: 138047497329600
# After: 138047497329600

# %%
mark = ("maths",80,"O")
if (mark[1]>75):
  print("distinction")
# Out:
# distinction

# %%
Attendence = ("P","A","P","P","A","P")
print("Total Present Days:", Attendence.count("P"))
print("Total Absent Days:", Attendence.count("A"))
if "A" in Attendence:
  print("Employee was absent at least once")
# Out:
# Total Present Days: 4
# Total Absent Days: 2
# Employee was absent at least once
